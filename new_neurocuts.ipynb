# %%
# !pip install gym
# !pip uninstall -y pyarrow
# !pip install ray[debug]==0.7.5
# !pip install setproctitle
# !pip install psutil
# !pip install gputil
# !pip install -U ray[rllib]==0.7.7
# !pip install pythonds
# Out:
# ...
# Uninstalling pyarrow-0.14.1:
#   Successfully uninstalled pyarrow-0.14.1
# ...
#      |████████████████████████████████| 74.9MB 141kB/s
# ...
#      |████████████████████████████████| 81kB 12.9MB/s
# ...
#      |████████████████████████████████| 2.9MB 36.4MB/s
# ...
#   Created wheel for setproctitle: filename=setproctitle-1.1.10-cp36-cp36m-linux_x86_64.whl size=33923 sha256=a3facdc35e47890c2337c69b9a0d8f477f4176b96cd83fa24f9630d6269069ec
#   Stored in directory: /root/.cache/pip/wheels/e6/b1/a6/9719530228e258eba904501fef99d5d85c80d52bd8f14438a3
# Successfully built setproctitle
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-cp36-none-any.whl size=7413 sha256=200404c9c3c67b70ccbc3048326d856ef8dd9e68083086f142db306370dea24b
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# ...
#      |████████████████████████████████| 73.8MB 57kB/s
# ...
#      |████████████████████████████████| 21.6MB 1.4MB/s
# ...

# %%
# !git clone https://github.com/elitonperin/new-trab-redes
# %cd new-trab-redes/
# Out:
# Cloning into 'new-trab-redes'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 133 (delta 69), reused 133 (delta 69), pack-reused 0
# Receiving objects: 100% (133/133), 22.53 MiB | 8.37 MiB/s, done.
# Resolving deltas: 100% (69/69), done.
# /content/new-trab-redes

# %%
# !python run_neurocuts.py --rules=acl5_1k --dump-dir=trees_local --fast --gpu

# %%
# !python run_neurocuts.py --rules=s_acl_40 --dump-dir=trees --fast --gpu
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#   experiment_tag: 0_rules=_content_new-trab-redes_neurocuts-master_classbench_s_acl_40,tree_gae_lambda=0.95
#   hostname: 8aed85539fe2
#   info:
#     grad_time_ms: 2748.999
#     learner:
#       default_policy:
#         cur_kl_coeff: 4.475396164771439e-10
#         cur_lr: 4.999999873689376e-05
#         entropy: 3.840687838874146e-07
#         entropy_coeff: 0.009999999776482582
#         kl: -1.058398767933566e-11
#         policy_loss: 0.0
#         total_loss: -3.847526297562354e-09
#         vf_explained_var: 1.0
#         vf_loss: 0.0
#     load_time_ms: 5.493
#     num_steps_sampled: 55363
#     num_steps_trained: 55100
#     sample_time_ms: 8089.271
#     update_time_ms: 0.003
#   iterations_since_restore: 55
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 66.55384615384615
#     gpu_util_percent0: 0.12461538461538463
# ...

# %%
# %cd NeuroCuts-Original/
# !python run_neurocuts.py --rules=s_acl_40 --dump-dir=trees/ --fast --gpu
# Out:
# /content/new-trab-redes/NeuroCuts-Original
# 2020-06-26 13:39:01.184034: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2020-06-26 13:39:04,748	INFO resource_spec.py:216 -- Starting Ray with 7.08 GiB memory available for workers and up to 3.56 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-06-26 13:39:05,251	WARNING sample.py:31 -- DeprecationWarning: wrapping <function on_episode_end at 0x7f2af9bc0f28> with tune.function() is no longer needed
# ...

# %%
# !python run_neurocuts.py --rules=acl5_1k \
    --dump-dir=trees_26 --num-workers=1 --gpu

# %%
#vf_explain_var

# %%
# !mv ../s_acl*.pkl trees/

# %%
#print neurocuts com EB
# !python inspect_tree.py trees/s_acl_40-3-acc-20-bytes-1592950717.8827252.pkl
# Out:
# This tree has 40 rules
# Tree stats: {'bytes_per_rule': 20.0, 'memory_access': 3, 'num_leaf_node': 20, 'num_nonleaf_node': 2, 'num_node': 22}
# Plottable visualization:
# widths,1,16,5
# dim0,0,0,0
# dim1,1,1,0
# dim2,0,0,0
# dim3,0,0,0
# dim4,0,0,0
#
# Layer 0
# ID:0	Action:('cut', 1, 32)	Depth:1	Range:	[0, 4294967296, 0, 4294967296, 0, 65536, 0, 65536, 0, 256]
# Children: 1 2 6 7 8 10 11 12 13 16 17 19 20 23 24 25
# Rules:
# src_ip:[738520417, 738520418) dst_ip:[759729122, 759729123) src_port:[0, 65536) dst_port:[1550, 1551) proto:[6, 7)
# src_ip:[738520436, 738520437) dst_ip:[1484430176, 1484430177) src_port:[0, 65536) dst_port:[1521, 1522) proto:[6, 7)
# src_ip:[741747831, 741747832) dst_ip:[2418173403, 2418173404) src_port:[0, 65536) dst_port:[1525, 1526) proto:[6, 7)
# src_ip:[741747831, 741747832) dst_ip:[1209321037, 1209321038) src_port:[0, 65536) dst_port:[2121, 2122) proto:[6, 7)
# ...

# %%
# print neurocuts
# !python inspect_tree.py trees-original/s_acl_40-3-acc-20-bytes-1593177645.9570315.pkl
# Out:
# This tree has 40 rules
# Tree stats: {'bytes_per_rule': 20.0, 'memory_access': 3, 'num_leaf_node': 20, 'num_nonleaf_node': 2, 'num_node': 22}
# Plottable visualization:
# widths,1,16,5
# dim0,0,0,0
# dim1,1,1,0
# dim2,0,0,0
# dim3,0,0,0
# dim4,0,0,0
#
# Layer 0
# ID:0	Action:('cut', 1, 32)	Depth:1	Range:	0 255.255.255.255 0 255.255.255.255 [0, 65536, 0, 65536, 0, 256]
# Children: 1 2 6 7 8 10 11 12 13 16 17 19 20 23 24 25
# Rules:
# src_ip:[44.4.237.97, 44.4.237.98) dst_ip:[45.72.139.226, 45.72.139.227) src_port:[0, 65536) dst_port:[1550, 1551) proto:[6, 7)
# src_ip:[44.4.237.116, 44.4.237.117) dst_ip:[88.122.155.96, 88.122.155.97) src_port:[0, 65536) dst_port:[1521, 1522) proto:[6, 7)
# src_ip:[44.54.44.119, 44.54.44.120) dst_ip:[144.34.101.219, 144.34.101.220) src_port:[0, 65536) dst_port:[1525, 1526) proto:[6, 7)
# src_ip:[44.54.44.119, 44.54.44.120) dst_ip:[72.20.198.77, 72.20.198.78) src_port:[0, 65536) dst_port:[2121, 2122) proto:[6, 7)
# ...

# %%
# %cd ..
# Out:
# /content/new-trab-redes
