# %%
#!/usr/bin/env python
# Use this to visualize and check the correctness of pickled tree files.

import argparse
import pickle
import random

parser = argparse.ArgumentParser()

parser.add_argument(
    "file", type=str, help="The tree pkl file to load and analyze.")


def print_info(tree):
    print("This tree has {} rules".format(len(tree.rules)))
    print("Tree stats: {}".format(tree.compute_result()))
    print("Plottable visualization:\n{}".format(tree.stats_str()))


def check_classification(tree):
    failures = 0
    for i in range(10000):
        if i % 100 == 0:
            print("Testing randomly sampled packets", i)
        if random.random() > 0.5:
            packet = random.choice(tree.rules).sample_packet()
        else:
            packet = (random.randint(0, 2**32 - 1), random.randint(
                0, 2**32 - 1), random.randint(0, 2**16 - 1),
                      random.randint(0, 2**16 - 1), random.randint(
                          0, 2**5 - 1))
        expected_match = None
        for r in tree.rules:
            if r.matches(packet):
                expected_match = r
                break
        actual_match = tree.match(packet)
        expected_match = expected_match and tree.rules.index(expected_match)
        actual_match = actual_match and tree.rules.index(actual_match)
        if expected_match != actual_match:
            print("actual", actual_match, "expected", expected_match)
            failures += 1
    assert failures == 0, failures


def check_invariants(node):
    if node.children:
        if not node.is_partition():
            _check_disjointness(node.children)
        _check_rule_distribution(node)
        for c in node.children:
            check_invariants(c)
    else:
        if len(node.rules) > 16:
            print("WARNING: leaf node found with {} rules".format(
                len(node.rules)))


def _check_rule_distribution(node):
    for r in node.pruned_rules():
        count = 0
        for n in node.children:
            if r in n.rules:
                assert n.is_intersect_multi_dimension(r.ranges)
                count += 1
        if count == 0:
            assert False, ("Rule not found in any children", node.id, r.ranges,
                           [n.ranges for n in node.children])


def _check_disjointness(nodes):
    for ni in nodes:
        for nj in nodes:
            if ni != nj:
                assert not ni.is_intersect_multi_dimension(nj.ranges), \
                    (ni.ranges, nj.ranges)

# %%
file_name = 'trees_23_06_23/acl5_1k-7-acc-24-bytes-1592970108.7114053.pkl'
file_name = 'trees_23_06/s_acl_40-3-acc-20-bytes-1592950717.8827252.pkl'
with open(file_name, "rb") as f:
    tree = pickle.load(f)
print_info(tree)
check_invariants(tree.root)
check_classification(tree)
# Out:
# This tree has 40 rules
# Tree stats: {'bytes_per_rule': 20.0, 'memory_access': 3, 'num_leaf_node': 20, 'num_nonleaf_node': 2, 'num_node': 22}
# Plottable visualization:
# widths,1,16,5
# dim0,0,0,0
# dim1,1,1,0
# dim2,0,0,0
# dim3,0,0,0
# dim4,0,0,0
#
# Testing randomly sampled packets 0
# Testing randomly sampled packets 100
# Testing randomly sampled packets 200
# Testing randomly sampled packets 300
# Testing randomly sampled packets 400
# Testing randomly sampled packets 500
# Testing randomly sampled packets 600
# Testing randomly sampled packets 700
# Testing randomly sampled packets 800
# Testing randomly sampled packets 900
# Testing randomly sampled packets 1000
# Testing randomly sampled packets 1100
# Testing randomly sampled packets 1200
# Testing randomly sampled packets 1300
# Testing randomly sampled packets 1400
# Testing randomly sampled packets 1500
# Testing randomly sampled packets 1600
# Testing randomly sampled packets 1700
# Testing randomly sampled packets 1800
# Testing randomly sampled packets 1900
# Testing randomly sampled packets 2000
# Testing randomly sampled packets 2100
# Testing randomly sampled packets 2200
# Testing randomly sampled packets 2300
# Testing randomly sampled packets 2400
# Testing randomly sampled packets 2500
# Testing randomly sampled packets 2600
# Testing randomly sampled packets 2700
# Testing randomly sampled packets 2800
# Testing randomly sampled packets 2900
# Testing randomly sampled packets 3000
# Testing randomly sampled packets 3100
# Testing randomly sampled packets 3200
# Testing randomly sampled packets 3300
# Testing randomly sampled packets 3400
# Testing randomly sampled packets 3500
# Testing randomly sampled packets 3600
# Testing randomly sampled packets 3700
# Testing randomly sampled packets 3800
# Testing randomly sampled packets 3900
# Testing randomly sampled packets 4000
# Testing randomly sampled packets 4100
# Testing randomly sampled packets 4200
# Testing randomly sampled packets 4300
# Testing randomly sampled packets 4400
# Testing randomly sampled packets 4500
# Testing randomly sampled packets 4600
# Testing randomly sampled packets 4700
# Testing randomly sampled packets 4800
# Testing randomly sampled packets 4900
# Testing randomly sampled packets 5000
# Testing randomly sampled packets 5100
# Testing randomly sampled packets 5200
# Testing randomly sampled packets 5300
# Testing randomly sampled packets 5400
# Testing randomly sampled packets 5500
# Testing randomly sampled packets 5600
# Testing randomly sampled packets 5700
# Testing randomly sampled packets 5800
# Testing randomly sampled packets 5900
# Testing randomly sampled packets 6000
# Testing randomly sampled packets 6100
# Testing randomly sampled packets 6200
# Testing randomly sampled packets 6300
# Testing randomly sampled packets 6400
# Testing randomly sampled packets 6500
# Testing randomly sampled packets 6600
# Testing randomly sampled packets 6700
# Testing randomly sampled packets 6800
# Testing randomly sampled packets 6900
# Testing randomly sampled packets 7000
# Testing randomly sampled packets 7100
# Testing randomly sampled packets 7200
# Testing randomly sampled packets 7300
# Testing randomly sampled packets 7400
# Testing randomly sampled packets 7500
# Testing randomly sampled packets 7600
# Testing randomly sampled packets 7700
# Testing randomly sampled packets 7800
# Testing randomly sampled packets 7900
# Testing randomly sampled packets 8000
# Testing randomly sampled packets 8100
# Testing randomly sampled packets 8200
# Testing randomly sampled packets 8300
# Testing randomly sampled packets 8400
# Testing randomly sampled packets 8500
# Testing randomly sampled packets 8600
# Testing randomly sampled packets 8700
# Testing randomly sampled packets 8800
# Testing randomly sampled packets 8900
# Testing randomly sampled packets 9000
# Testing randomly sampled packets 9100
# Testing randomly sampled packets 9200
# Testing randomly sampled packets 9300
# Testing randomly sampled packets 9400
# Testing randomly sampled packets 9500
# Testing randomly sampled packets 9600
# Testing randomly sampled packets 9700
# Testing randomly sampled packets 9800
# Testing randomly sampled packets 9900

# %%
dir(tree)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_compute_memory_access',
#  '_split',
#  'check_contiguous_region',
#  'compute_result',
#  'create_node',
#  'current_node',
#  'cut_current_node',
#  'cut_current_node_multi_dimension',
#  'cut_current_node_split',
#  'cut_node',
#  'depth',
#  'get_current_node',
#  'get_depth',
#  'get_next_node',
#  'get_stats',
#  'is_finish',
#  'is_leaf',
#  'leaf_threshold',
#  'match',
#  'merge_region',
#  'node_count',
#  'nodes_to_cut',
#  'partition_current_node',
#  'partition_cutsplit',
#  'partition_efficuts',
#  'partition_node',
#  'print_layers',
#  'print_stats',
#  'refinement_equi_dense',
#  'refinement_node_merging',
#  'refinement_region_compaction',
#  'refinement_rule_overlay',
#  'refinement_rule_pushup',
#  'refinements',
#  'root',
#  'rules',
#  'stats_str',
#  'update_tree']

# %%
tree.print_layers()
tree.node_count
tree.compute_result()
# Out:
# Layer 0
# ID:0	Action:('cut', 1, 32)	Depth:1	Range:	[0, 4294967296, 0, 4294967296, 0, 65536, 0, 65536, 0, 256]
# Children: 1 2 6 7 8 10 11 12 13 16 17 19 20 23 24 25
# Rules:
# src_ip:[738520417, 738520418) dst_ip:[759729122, 759729123) src_port:[0, 65536) dst_port:[1550, 1551) proto:[6, 7)
# src_ip:[738520436, 738520437) dst_ip:[1484430176, 1484430177) src_port:[0, 65536) dst_port:[1521, 1522) proto:[6, 7)
# src_ip:[741747831, 741747832) dst_ip:[2418173403, 2418173404) src_port:[0, 65536) dst_port:[1525, 1526) proto:[6, 7)
# src_ip:[741747831, 741747832) dst_ip:[1209321037, 1209321038) src_port:[0, 65536) dst_port:[2121, 2122) proto:[6, 7)
# src_ip:[738520417, 738520418) dst_ip:[1450320456, 1450320457) src_port:[0, 65536) dst_port:[1221, 1222) proto:[6, 7)
# src_ip:[738520417, 738520418) dst_ip:[1450320508, 1450320509) src_port:[0, 65536) dst_port:[30211, 30212) proto:[6, 7)
# src_ip:[741747833, 741747834) dst_ip:[3148974982, 3148974983) src_port:[0, 65536) dst_port:[1526, 1527) proto:[6, 7)
# src_ip:[741747833, 741747834) dst_ip:[3190408869, 3190408870) src_port:[0, 65536) dst_port:[1526, 1527) proto:[6, 7)
# src_ip:[738520438, 738520440) dst_ip:[2068446529, 2068446530) src_port:[0, 65536) dst_port:[1521, 1522) proto:[6, 7)
# src_ip:[738520438, 738520440) dst_ip:[890667620, 890667621) src_port:[0, 65536) dst_port:[1724, 1725) proto:[6, 7)
# src_ip:[11539382, 2954082304) dst_ip:[890667620, 890667621) src_port:[0, 65536) dst_port:[1717, 1718) proto:[6, 7)
# src_ip:[11539382, 2954082304) dst_ip:[890667620, 890667621) src_port:[0, 65536) dst_port:[1708, 1709) proto:[6, 7)
# src_ip:[1483495651, 1483495652) dst_ip:[16159740, 16159741) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[1483495679, 1483495680) dst_ip:[16159740, 16159741) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[11539382, 2954082304) dst_ip:[738520290, 738520291) src_port:[0, 65536) dst_port:[0, 65536) proto:[1, 2)
# src_ip:[11539382, 2954082304) dst_ip:[2068446530, 2068446531) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[92315052, 92315054) dst_ip:[13807786, 13807787) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11539382, 2954082304) dst_ip:[2068446529, 2068446530) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11589812, 1483496448) dst_ip:[53940, 53941) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[11589810, 1483495936) dst_ip:[63120, 63121) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[0, 4294967296) dst_ip:[136, 137) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[0, 4294967296) dst_ip:[144, 145) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11539382, 2954082304) dst_ip:[244, 245) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11539380, 2954081536) dst_ip:[0, 1) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11589812, 1483496448) dst_ip:[192, 193) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11539382, 2954082304) dst_ip:[0, 1) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[0, 2147483648) dst_ip:[248, 249) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[180, 1543503872) dst_ip:[128, 129) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[176, 1543503872) dst_ip:[0, 1) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[0, 4294967296) dst_ip:[138, 139) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11589812, 1483496448) dst_ip:[7734, 7735) src_port:[0, 65536) dst_port:[0, 65536) proto:[1, 2)
# src_ip:[11589816, 1483497472) dst_ip:[63122, 63123) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[11589792, 1483495424) dst_ip:[53940, 53941) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[11589812, 1483496448) dst_ip:[63124, 63125) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[1483495676, 1483495678) dst_ip:[16159740, 16159741) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[369260209, 369260210) dst_ip:[13810144, 13810145) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[738520437, 738520438) dst_ip:[6956880, 6956881) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[92315054, 92315055) dst_ip:[13807792, 13807793) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[46359239, 46359240) dst_ip:[2953895416, 2953895417) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[1483495679, 1483495680) dst_ip:[2068446530, 2068446531) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
#
# Layer 1
# ID:1	Action:('cut', 1, 32)	Depth:2	Range:	[0, 4294967296, 0, 134217728, 0, 65536, 0, 65536, 0, 256]
# Children: 33 34 35 36 37
# Rules:
# src_ip:[1483495651, 1483495652) dst_ip:[16159740, 16159741) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[1483495679, 1483495680) dst_ip:[16159740, 16159741) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[92315052, 92315054) dst_ip:[13807786, 13807787) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11589812, 1483496448) dst_ip:[53940, 53941) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[11589810, 1483495936) dst_ip:[63120, 63121) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[0, 4294967296) dst_ip:[136, 137) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[0, 4294967296) dst_ip:[144, 145) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11539382, 2954082304) dst_ip:[244, 245) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11539380, 2954081536) dst_ip:[0, 1) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11589812, 1483496448) dst_ip:[192, 193) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11539382, 2954082304) dst_ip:[0, 1) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[0, 2147483648) dst_ip:[248, 249) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[180, 1543503872) dst_ip:[128, 129) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[176, 1543503872) dst_ip:[0, 1) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[0, 4294967296) dst_ip:[138, 139) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11589812, 1483496448) dst_ip:[7734, 7735) src_port:[0, 65536) dst_port:[0, 65536) proto:[1, 2)
# src_ip:[11589816, 1483497472) dst_ip:[63122, 63123) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[11589792, 1483495424) dst_ip:[53940, 53941) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[11589812, 1483496448) dst_ip:[63124, 63125) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[1483495676, 1483495678) dst_ip:[16159740, 16159741) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[369260209, 369260210) dst_ip:[13810144, 13810145) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[738520437, 738520438) dst_ip:[6956880, 6956881) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[92315054, 92315055) dst_ip:[13807792, 13807793) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
#
# ID:2	Action:None	Depth:2	Range:	[0, 4294967296, 134217728, 671088640, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
#
# ID:6	Action:None	Depth:2	Range:	[0, 4294967296, 671088640, 805306368, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# src_ip:[738520417, 738520418) dst_ip:[759729122, 759729123) src_port:[0, 65536) dst_port:[1550, 1551) proto:[6, 7)
# src_ip:[11539382, 2954082304) dst_ip:[738520290, 738520291) src_port:[0, 65536) dst_port:[0, 65536) proto:[1, 2)
#
# ID:7	Action:None	Depth:2	Range:	[0, 4294967296, 805306368, 939524096, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# src_ip:[738520438, 738520440) dst_ip:[890667620, 890667621) src_port:[0, 65536) dst_port:[1724, 1725) proto:[6, 7)
# src_ip:[11539382, 2954082304) dst_ip:[890667620, 890667621) src_port:[0, 65536) dst_port:[1717, 1718) proto:[6, 7)
# src_ip:[11539382, 2954082304) dst_ip:[890667620, 890667621) src_port:[0, 65536) dst_port:[1708, 1709) proto:[6, 7)
#
# ID:8	Action:None	Depth:2	Range:	[0, 4294967296, 939524096, 1207959552, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
#
# ID:10	Action:None	Depth:2	Range:	[0, 4294967296, 1207959552, 1342177280, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# src_ip:[741747831, 741747832) dst_ip:[1209321037, 1209321038) src_port:[0, 65536) dst_port:[2121, 2122) proto:[6, 7)
#
# ID:11	Action:None	Depth:2	Range:	[0, 4294967296, 1342177280, 1476395008, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# src_ip:[738520417, 738520418) dst_ip:[1450320456, 1450320457) src_port:[0, 65536) dst_port:[1221, 1222) proto:[6, 7)
# src_ip:[738520417, 738520418) dst_ip:[1450320508, 1450320509) src_port:[0, 65536) dst_port:[30211, 30212) proto:[6, 7)
#
# ID:12	Action:None	Depth:2	Range:	[0, 4294967296, 1476395008, 1610612736, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# src_ip:[738520436, 738520437) dst_ip:[1484430176, 1484430177) src_port:[0, 65536) dst_port:[1521, 1522) proto:[6, 7)
#
# ID:13	Action:None	Depth:2	Range:	[0, 4294967296, 1610612736, 2013265920, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
#
# ID:16	Action:None	Depth:2	Range:	[0, 4294967296, 2013265920, 2147483648, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# src_ip:[738520438, 738520440) dst_ip:[2068446529, 2068446530) src_port:[0, 65536) dst_port:[1521, 1522) proto:[6, 7)
# src_ip:[11539382, 2954082304) dst_ip:[2068446530, 2068446531) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[11539382, 2954082304) dst_ip:[2068446529, 2068446530) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[1483495679, 1483495680) dst_ip:[2068446530, 2068446531) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
#
# ID:17	Action:None	Depth:2	Range:	[0, 4294967296, 2147483648, 2415919104, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
#
# ID:19	Action:None	Depth:2	Range:	[0, 4294967296, 2415919104, 2550136832, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# src_ip:[741747831, 741747832) dst_ip:[2418173403, 2418173404) src_port:[0, 65536) dst_port:[1525, 1526) proto:[6, 7)
#
# ID:20	Action:None	Depth:2	Range:	[0, 4294967296, 2550136832, 2952790016, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
#
# ID:23	Action:None	Depth:2	Range:	[0, 4294967296, 2952790016, 3087007744, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# src_ip:[46359239, 46359240) dst_ip:[2953895416, 2953895417) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
#
# ID:24	Action:None	Depth:2	Range:	[0, 4294967296, 3087007744, 3221225472, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# src_ip:[741747833, 741747834) dst_ip:[3148974982, 3148974983) src_port:[0, 65536) dst_port:[1526, 1527) proto:[6, 7)
# src_ip:[741747833, 741747834) dst_ip:[3190408869, 3190408870) src_port:[0, 65536) dst_port:[1526, 1527) proto:[6, 7)
#
# ID:25	Action:None	Depth:2	Range:	[0, 4294967296, 3221225472, 4294967296, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
#
# Layer 2
# ID:33	Action:None	Depth:3	Range:	[0, 4294967296, 0, 4194304, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# src_ip:[11589812, 1483496448) dst_ip:[53940, 53941) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[11589810, 1483495936) dst_ip:[63120, 63121) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[0, 4294967296) dst_ip:[136, 137) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[0, 4294967296) dst_ip:[144, 145) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11539382, 2954082304) dst_ip:[244, 245) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11539380, 2954081536) dst_ip:[0, 1) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11589812, 1483496448) dst_ip:[192, 193) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11539382, 2954082304) dst_ip:[0, 1) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[0, 2147483648) dst_ip:[248, 249) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[180, 1543503872) dst_ip:[128, 129) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[176, 1543503872) dst_ip:[0, 1) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[0, 4294967296) dst_ip:[138, 139) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[11589812, 1483496448) dst_ip:[7734, 7735) src_port:[0, 65536) dst_port:[0, 65536) proto:[1, 2)
# src_ip:[11589816, 1483497472) dst_ip:[63122, 63123) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[11589792, 1483495424) dst_ip:[53940, 53941) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[11589812, 1483496448) dst_ip:[63124, 63125) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
#
# ID:34	Action:None	Depth:3	Range:	[0, 4294967296, 4194304, 8388608, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# src_ip:[738520437, 738520438) dst_ip:[6956880, 6956881) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
#
# ID:35	Action:None	Depth:3	Range:	[0, 4294967296, 8388608, 12582912, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
#
# ID:36	Action:None	Depth:3	Range:	[0, 4294967296, 12582912, 16777216, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# src_ip:[1483495651, 1483495652) dst_ip:[16159740, 16159741) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[1483495679, 1483495680) dst_ip:[16159740, 16159741) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[92315052, 92315054) dst_ip:[13807786, 13807787) src_port:[0, 65536) dst_port:[0, 65536) proto:[0, 256)
# src_ip:[1483495676, 1483495678) dst_ip:[16159740, 16159741) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[369260209, 369260210) dst_ip:[13810144, 13810145) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
# src_ip:[92315054, 92315055) dst_ip:[13807792, 13807793) src_port:[0, 65536) dst_port:[0, 65536) proto:[6, 7)
#
# ID:37	Action:None	Depth:3	Range:	[0, 4294967296, 16777216, 134217728, 0, 65536, 0, 65536, 0, 256]
# Children:
# Rules:
# {'bytes_per_rule': 20.0,
#  'memory_access': 3,
#  'num_leaf_node': 20,
#  'num_nonleaf_node': 2,
#  'num_node': 22}
